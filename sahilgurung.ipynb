# %%
pairs=[("sports","win"),("sports","loss"),("sports","win"),("sports","win")
win_count=0
loss_count=0
if catogery,result in pairs:
    if catogery == "sports":
        if result == "win":
            win_count+=1
        else:
            loss_count+=1
print("sports win count;",win_countin)
print("sports loss count;",loss_count)
# Out:
#   Cell In[15], line 1
#     pairs=[("sports","win"),("sports","loss"),("sports","win"),("sports","win")
#           ^
# SyntaxError: '[' was never closed

# %%
a=(1,2,3,5)
missing_number= []
for num in range(min(a), max(a)+1):
    if num not in a:
        missing_number.append(num)
print("missing number:", missing_number)
# Out:
# missing number: [4]

# %%
item =["A",90, "B", 80, "C", 85]
k = 2
score = sorted([score for name, score in item], reverse=True)
kth_score = scores[k-1]

result = []
for name, score in items:
    if score == kth_score:
        result.append((name, score))

print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 item =["A",90, "B", 80, "C", 85]
#       2 k = 2
# ----> 3 score = sorted([score for name, score in item], reverse=True)
#       4 kth_score = scores[k-1]
#       6 result = []
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
def add_unique(x, seen=None):
    if seen is None:
        seen = set()
    if x not in seen:
        seen.add(x)
    return list(seen)

print(add_unique(1))
print(add_unique(2))
# Out:
# [1]
# [2]

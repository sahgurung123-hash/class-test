# %%
class student:
    school_name='upes'
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
s1 =student('ramy',15)
s2 =student('samy',19 )
        
print("school:",s1.school_name)
print("school:",s2.school_name)

print("student 1:",s1.name,s1.age)
print("student 2:",s2.name,s2.age)
# Out:
# school: upes
# school: upes
# student 1: ramy 15
# student 2: samy 19

# %%
class Employee:
    company = "abc"

    def __init__(self,name,salery):
        self.name=name
        self.salary=salery

    def show_details(self):
            print(self.name,self.salary,Employee.company)
    @classmethod
    def change_company(cls,new_company):
                cls.company=new_name
e1.show_details()
e2.show_details()
Employee.change_company="ccc"
e1.show_details()
e2.show_details()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 13
#      10     @classmethod
#      11     def change_company(cls,new_company):
#      12                 cls.company=new_name
# ---> 13 e1.show_details()
#      14 e2.show_details()
#      15 Employee.change_company="ccc"
#
# NameError: name 'e1' is not defined

# %%
class mathelper:
    @staticmethod
    def is_even(num):
        if num % 2 == 0:
            return True
        else:
            return False
print(mathelper.is_even(8))
print(mathelper.is_even(11))
# Out:
# True
# False

# %%
class bankaccount:
    def __init_(self, name, balance)
        self.name = name
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
    
    def withdraw(self, amount):
        if amount <=self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balamce")
    
    def show_balance(self):
        print("balance:",self.__balance)

acc = bankaccount("Ram", 1000)
acc.deposit(500)
acc.withdrawl(300)
acc.show_balance()
